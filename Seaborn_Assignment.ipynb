# %%
import seaborn as sns

# %%
""" Q.1
Seaborn is a powerful Python data visualization library built on top of Matplotlib. It provides a high-level interface for creating informative and aesthetically pleasing statistical graphics.
Seaborn is particularly useful for visualizing complex datasets and performing advanced statistical analyses. Here are some of the types of plots that can be created using Seaborn:
1. Histograms: Seaborn's distplot() or histplot() functions allow you to create histograms to visualize the distribution of a single variable.
2. Bar Plots: Seaborn provides versatile functions like barplot() and countplot() for creating bar plots to compare values across different categories.
3. Box Plots: Seaborn have functions like boxplot() which creates box plots to display the distribution of data and identify outliers.
4. Heatmaps: Seaborn's heatmap() function produces colored heatmaps to visualize matrices or 2D datasets.
5. Joint Plots: Seaborn's jointplot() creates scatter plots with marginal histograms or density plots to explore bivariate relationships.
These are some of the functions of Seaborn.

# %%
# Q.2

# %%
fmri=sns.load_dataset("fmri") # loading fmri dataset from seaborn

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
# Plotting a line plot using x ="timepoint" and y = "signal" for different events and regions.

# %%
sns.lineplot(x=fmri.timepoint,y=fmri.signal,data=fmri,hue="event",style="region") #plotting lineplot with timepoint as x axis and signal as y axis
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
# Q.3

# %%
titanic_dataset=sns.load_dataset('titanic')

# %%
titanic_dataset
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.boxplot(x=titanic_dataset.pclass,y=titanic_dataset.age)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(x=titanic_dataset.pclass,y=titanic_dataset.fare)
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
# Q.4

# %%
diamond_dataset=sns.load_dataset("diamonds") # creating a diamond dataset

# %%
diamond_dataset
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
 sns.histplot(x="price",data=diamond_dataset,hue="cut",multiple='stack',bins=20)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
#The histplot() function is used here to create a histogram for the 'price' column, and the hue parameter is set to 'cut' to differentiate the histogram bars based on the 'cut' column.

# %%
# Q.5

# %%
iris=sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris,hue="species")  # creating a pairplot of iris dataset

# %%
# Q.6

# %%
flight=sns.load_dataset("flights")

# %%
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flight_table=flight.pivot_table(index='month',columns='year',values='passengers')
sns.heatmap(flight_table)  # plotting heatmap of flights dataset
plt.title('Heatmap of flight passengers')
# Out:
# Text(0.5, 1.0, 'Heatmap of flight passengers')

# %%
# Here we're using pivot_table() to create a pivot of the dataset that's suitable for a heatmap, with months on the y-axis and years on the x-axis, and the 'passengers' column as the values.The heatmap() function creates the heatmap using the pivot data.
